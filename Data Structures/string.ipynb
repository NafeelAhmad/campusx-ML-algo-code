# %%
a1 = "hello"
a2 = "Lamb"
a3 = "llm"
print(id(a1))
print(id(a3))
a4 = a3
print(a4)
print(id(a3))
print(a1+a2)
#print(a1/3)
# Out:
# 2111727579712
# 2111733319024
# llm
# 2111733319024
# helloLamb

# %%
a4.capitalize()
# Out:
# 'Llm'

# %%
a4.center(9,"*")
# Out:
# '***llm***'

# %%
a1.count('l',0,len(a1))
# Out:
# 2

# %%
a1.startswith('h',0,len(a1))
# Out:
# True
